# %% [markdown]
# ## 1. 환경 초기화

# %% [markdown]
# ### 1-1. 분석 목표 설정

# %% [markdown]
# ### 1-2. 데이터 할당

# %% [markdown]
# ## 2. 데이터 수집

# %% [markdown]
# ### 2-1. 데이터 정의

# %% [markdown]
# ### 2-2. 데이터 출처 탐색 및 수집

# %% [markdown]
# ### 2-3. 데이터 검증 (정확성, 결측치 유무 확인)

# %% [markdown]
# ## 3. 데이터 전처리

# %% [markdown]
# ### 3-1. 결측치 처리

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

'''0. raw data 전처리 과정'''

#월별(month) / 일별(day)데이터를 나눠 데이터 전처리

# df_month = pd.read_csv('KRW_Month.csv', encoding='cp949')
# df_day = pd.read_csv('KRW_Day.csv', encoding='cp949')


# df_month.head()
# Out:
# '0. raw data 전처리 과정'

# %%
df_day.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df_day.head()
#
# NameError: name 'df_day' is not defined

# %%
# df_month.plot()
# df_day.plot()

# %%
'''1. political index 전처리 과정'''

from google.colab import drive
drive.mount('/content/drive')

df_political_raw = pd.read_csv('P_Data_Extract_From_Worldwide_Governance.csv', encoding='cp949')

df_political = df_political_raw.transpose()


df_political.rename(columns=df_political.iloc[0], inplace=True)	# 행열이 전환된 데이터프레임의 열 이름 제대로 수정
df_political = df_political.drop(df_political.index[0])
df_political.dropna(axis=1)
df_political.head()

os.chdir('/content')
df_political.to_csv('df_political.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Out:
#                                                               0   \
# Country Name                                               India
# Series Name    Political Stability and Absence of Violence/Te...
# 2010 [YR2010]                                          -1.277985
# 2011 [YR2011]                                          -1.326795
# 2012 [YR2012]                                           -1.28931
# 2013 [YR2013]                                          -1.229174
# 2014 [YR2014]                                          -0.997912
# 2015 [YR2015]                                          -0.954774
# 2016 [YR2016]                                          -0.960427
# 2017 [YR2017]                                          -0.774099
# 2018 [YR2018]                                          -0.997705
# 2019 [YR2019]                                          -0.796841
# 2020 [YR2020]                                          -0.841136
# 2021 [YR2021]                                          -0.691998
# 2022 [YR2022]                                          -0.568608
#
#                                                1   \
# Country Name                                India
# Series Name    Government Effectiveness: Estimate
# 2010 [YR2010]                            0.031656
# 2011 [YR2011]                            0.022554
# 2012 [YR2012]                           -0.156087
# 2013 [YR2013]                           -0.156966
# 2014 [YR2014]                           -0.222162
# 2015 [YR2015]                            0.080022
# 2016 [YR2016]                            0.061384
# 2017 [YR2017]                            0.040756
# 2018 [YR2018]                            0.262749
# 2019 [YR2019]                            0.130845
# 2020 [YR2020]                            0.375041
# 2021 [YR2021]                            0.250856
# 2022 [YR2022]                            0.370331
#
#                                                               2   \
# Country Name                                         Korea, Rep.
# Series Name    Political Stability and Absence of Violence/Te...
# 2010 [YR2010]                                           0.325896
# 2011 [YR2011]                                           0.412496
# 2012 [YR2012]                                           0.267103
# 2013 [YR2013]                                           0.278579
# 2014 [YR2014]                                           0.108569
# 2015 [YR2015]                                           0.156361
# 2019 [YR2019]                            1.453559
# 2020 [YR2020]                            1.275138
# 2021 [YR2021]                             1.29952
# 2022 [YR2022]                            1.255993
#
#                                                               20  \
# Country Name                                  Russian Federation
# Series Name    Political Stability and Absence of Violence/Te...
# 2010 [YR2010]                                          -0.929459
# 2011 [YR2011]                                          -0.998262
# 2012 [YR2012]                                          -0.817713
# 2013 [YR2013]                                          -0.736094
# 2014 [YR2014]                                          -0.943617
# 2015 [YR2015]                                          -1.032223
# 2016 [YR2016]                                          -0.947688
# 2017 [YR2017]                                           -0.64276
# 2018 [YR2018]                                          -0.538376
# 2019 [YR2019]                                          -0.551099
# 2020 [YR2020]                                          -0.667409
# 2021 [YR2021]                                          -0.707902
# 2022 [YR2022]                                          -0.918995
#
#                                                21
# Country Name                   Russian Federation
# Series Name    Government Effectiveness: Estimate
# 2010 [YR2010]                           -0.601687
# 2011 [YR2011]                           -0.601445
# 2012 [YR2012]                           -0.534915
# 2013 [YR2013]                           -0.452165
# 2014 [YR2014]                           -0.194581
# 2015 [YR2015]                           -0.331283
# 2016 [YR2016]                           -0.323035
# 2017 [YR2017]                           -0.190597
# 2018 [YR2018]                           -0.103585
# 2019 [YR2019]                            0.024325
# 2020 [YR2020]                           -0.110943
# 2021 [YR2021]                           -0.210496
# 2022 [YR2022]                           -0.695411
#
# [15 rows x 22 columns]

# %% [markdown]
# ### 3-2. 이상치 처리

# %% [markdown]
# ### 3-3. 데이터 정규화

# %% [markdown]
# ## 4. 모델 구축

# %% [markdown]
# ### 4-1. 변수 선택

# %%
# pwd
# Out:
# '/content'

# %%
# PsI (Political Score Index) 데이터 전처리
import pandas as pd
import matplotlib.pyplot as plt
import os

from google.colab import drive
drive.mount('/content/drive')

df_political = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/dataset/df_political.csv', encoding='cp949')
df = df_political
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = df_political
# 결측치 확인
df.isnull()
# 모든 데이터가 NaN 인 경우, 해당 컬럼을 삭제
df = df.dropna(axis = 'columns', how = 'all')
# 새 테이블을 만들고
df.isnull()

# df_political.dtypes
# for i in range(len(df_political)):
  # df['india_PSA+GE'] = df['India'] + df['India.1']
# Out:
#     Unnamed: 0  India  India.1  Korea, Rep.  Korea, Rep..1  China  China.1  \
# 0        False  False    False        False          False  False    False
# 1        False  False    False        False          False  False    False
# 2        False  False    False        False          False  False    False
# 3        False  False    False        False          False  False    False
# 4        False  False    False        False          False  False    False
# 5        False  False    False        False          False  False    False
# 6        False  False    False        False          False  False    False
# 7        False  False    False        False          False  False    False
# 8        False  False    False        False          False  False    False
# 9        False  False    False        False          False  False    False
# 10       False  False    False        False          False  False    False
# 11       False  False    False        False          False  False    False
# 12       False  False    False        False          False  False    False
# 13       False  False    False        False          False  False    False
#
#     Japan  Japan.1  France  ...  Italy  Italy.1  Switzerland  Switzerland.1  \
# 0   False    False   False  ...  False    False        False          False
# 1   False    False   False  ...  False    False        False          False
# 2   False    False   False  ...  False    False        False          False
# 3   False    False   False  ...  False    False        False          False
# 4   False    False   False  ...  False    False        False          False
# 5   False    False   False  ...  False    False        False          False
# 6   False    False   False  ...  False    False        False          False
# 7   False    False   False  ...  False    False        False          False
# 8   False    False   False  ...  False    False        False          False
# 9   False    False   False  ...  False    False        False          False
# 10  False    False   False  ...  False    False        False          False
# 11  False    False   False  ...  False    False        False          False
# 12  False    False   False  ...  False    False        False          False
# 13  False    False   False  ...  False    False        False          False
#
#     Australia  Australia.1  United States  United States.1  \
# 0       False        False          False            False
# 1       False        False          False            False
# 2       False        False          False            False
# 3       False        False          False            False
# 4       False        False          False            False
# 5       False        False          False            False
# 6       False        False          False            False
# 7       False        False          False            False
# 8       False        False          False            False
# 9       False        False          False            False
# 10      False        False          False            False
# 11      False        False          False            False
# 12      False        False          False            False
# 13      False        False          False            False
#
#     Russian Federation  Russian Federation.1
# 0                False                 False
# 1                False                 False
# 2                False                 False
# 3                False                 False
# 4                False                 False
# 5                False                 False
# 6                False                 False
# 7                False                 False
# 8                False                 False
# 9                False                 False
# 10               False                 False
# 11               False                 False
# 12               False                 False
# 13               False                 False
#
# [14 rows x 23 columns]

# %%
# 폰트 깨짐 현상 해결
# 참고 : https://teddylee777.github.io/colab/colab-korean/
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# %% [markdown]
# ### 4-2. 변수 선택2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam

from tensorflow import keras
from keras.layers import Dense
from keras.models import Sequential, load_model

# 샘플 데이터 생성
# np.random.seed(0)

# 날짜 범위 생성
# date_range = pd.date_range(start='2010-01-01', end='2022-12-31', freq='MS')
date_range = pd.date_range(start='2010-01-01', end='2022-12-31', freq='M')

###

# 랜덤 다변량 데이터 생성 (환율, 주가, 금리 등)
num_samples = len(date_range)
exchange_rate = 100 + np.cumsum(np.random.randn(num_samples))
stock_price = 1000 + np.cumsum(np.random.randn(num_samples))
interest_rate = 0.02 + np.cumsum(0.001 * np.random.randn(num_samples))

print('date_range >> ', date_range)
print('num_smaples >> ', num_samples)
print('exchange_rate : >> ', exchange_rate.shape)
print('stock_price ', stock_price.shape)
print('interest_rate : >> ', interest_rate.shape)
# Out:
# date_range >>  DatetimeIndex(['2010-01-01', '2010-02-01', '2010-03-01', '2010-04-01',
#                '2010-05-01', '2010-06-01', '2010-07-01', '2010-08-01',
#                '2010-09-01', '2010-10-01',
#                ...
#                '2022-03-01', '2022-04-01', '2022-05-01', '2022-06-01',
#                '2022-07-01', '2022-08-01', '2022-09-01', '2022-10-01',
#                '2022-11-01', '2022-12-01'],
#               dtype='datetime64[ns]', length=156, freq='MS')
# num_smaples >>  156
# exchange_rate : >>  (156,)
# stock_price  (156,)
# interest_rate : >>  (156,)

# %%
# 데이터프레임 생성
data = pd.DataFrame({'Date': date_range, 'ExchangeRate': exchange_rate, 'StockPrice': stock_price, 'InterestRate': interest_rate})
data.set_index('Date', inplace=True)

# 데이터 시각화
plt.figure(figsize=(12, 6))
plt.plot(data['ExchangeRate'], label='Exchange Rate')
plt.plot(data['StockPrice'], label='Stock Price')
plt.plot(data['InterestRate'], label='Interest Rate')
plt.legend()
plt.title('다변량 데이터 시각화')
plt.show()

# 데이터 정규화
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(data)

# 학습 데이터와 테스트 데이터 분리
train_size = int(len(scaled_data) * 0.8)
train_data, test_data = scaled_data[:train_size], scaled_data[train_size:]

# 시계열 데이터를 입력 시퀀스로 변환
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i+seq_length])
        y.append(data[i+seq_length])
    return np.array(X), np.array(y)

seq_length = 30  # 시퀀스 길이 설정
X_train, y_train = create_sequences(train_data, seq_length)
X_test, y_test = create_sequences(test_data, seq_length)

# LSTM 모델 생성
model = Sequential()
model.add(LSTM(50, activation='relu', input_shape=(seq_length, 3)))
model.add(Dense(3))  # 출력 노드 수는 다변량 데이터의 변수 개수와 동일해야 함

# 모델 컴파일
model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')

########
# 모델 학습
model.fit(X_train, y_train, epochs=100, batch_size=64)

# 모델 평가
test_loss = model.evaluate(X_test, y_test)
print(f"테스트 데이터 손실: {test_loss:.4f}")

# 예측
y_pred = model.predict(X_test)

# 정규화된 데이터를 원래 스케일로 변환
y_test = scaler.inverse_transform(y_test)
y_pred = scaler.inverse_transform(y_pred)

# 시각화
plt.figure(figsize=(12, 6))
plt.plot(data.index[-len(y_test):], y_test[:, 0], label='실제 환율')
plt.plot(data.index[-len(y_pred):], y_pred[:, 0], label='예측 환율')
plt.legend()
plt.title('다변량 환율 예측 결과')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45796 (\N{HANGUL SYLLABLE DA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48320 (\N{HANGUL SYLLABLE BYEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47049 (\N{HANGUL SYLLABLE RYANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45936 (\N{HANGUL SYLLABLE DE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 53552 (\N{HANGUL SYLLABLE TEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44033 (\N{HANGUL SYLLABLE GAG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# Epoch 1/100
# 2/2 [==============================] - 4s 51ms/step - loss: 0.2325
# Epoch 2/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2100
# Epoch 3/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1888
# Epoch 4/100
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1677
# Epoch 5/100
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1469
# Epoch 6/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.1260
# Epoch 7/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1056
# Epoch 8/100
# 2/2 [==============================] - 0s 59ms/step - loss: 0.0836
# Epoch 9/100
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0619
# Epoch 10/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0424
# Epoch 11/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0433
# Epoch 12/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0432
# Epoch 13/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0330
# Epoch 14/100
# 2/2 [==============================] - 0s 55ms/step - loss: 0.0279
# Epoch 15/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0271
# Epoch 16/100
# 2/2 [==============================] - 0s 41ms/step - loss: 0.0262
# Epoch 17/100
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0242
# Epoch 18/100
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0213
# Epoch 19/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0186
# Epoch 20/100
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0166
# Epoch 21/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0153
# Epoch 22/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0145
# Epoch 23/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0138
# Epoch 24/100
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0130
# Epoch 25/100
# 2/2 [==============================] - 0s 41ms/step - loss: 0.0123
# Epoch 26/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0124
# Epoch 27/100
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0119
# Epoch 28/100
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0114
# Epoch 29/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0108
# Epoch 30/100
# 2/2 [==============================] - 0s 61ms/step - loss: 0.0102
# Epoch 31/100
# 2/2 [==============================] - 0s 68ms/step - loss: 0.0100
# Epoch 32/100
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0097
# Epoch 33/100
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0093
# Epoch 34/100
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0089
# Epoch 35/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0086
# Epoch 36/100
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0086
# Epoch 37/100
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0081
# Epoch 38/100
# 2/2 [==============================] - 0s 77ms/step - loss: 0.0079
# Epoch 39/100
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0078
# Epoch 40/100
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0075
# Epoch 41/100
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0073
# Epoch 42/100
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0072
# Epoch 43/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0069
# Epoch 44/100
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0067
# Epoch 45/100
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0066
# Epoch 46/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0064
# Epoch 47/100
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0063
# Epoch 48/100
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0061
# Epoch 49/100
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0059
# Epoch 50/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0058
# Epoch 51/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.0056
# Epoch 52/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0055
# Epoch 53/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0054
# Epoch 54/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0052
# Epoch 55/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0051
# Epoch 56/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0049
# Epoch 57/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0048
# Epoch 58/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0047
# Epoch 59/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0047
# Epoch 60/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0046
# Epoch 61/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0044
# Epoch 62/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0044
# Epoch 63/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0044
# Epoch 64/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0043
# Epoch 65/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0043
# Epoch 66/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0042
# Epoch 67/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0042
# Epoch 68/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0041
# Epoch 69/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0041
# Epoch 70/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0040
# Epoch 71/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0040
# Epoch 72/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0039
# Epoch 73/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0039
# Epoch 74/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0039
# Epoch 75/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0038
# Epoch 76/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0038
# Epoch 77/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0037
# Epoch 78/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0037
# Epoch 79/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0038
# Epoch 80/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0037
# Epoch 81/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0036
# Epoch 82/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0036
# Epoch 83/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0036
# Epoch 84/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0035
# Epoch 85/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0035
# Epoch 86/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0035
# Epoch 87/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0034
# Epoch 88/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0034
# Epoch 89/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0034
# Epoch 90/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0033
# Epoch 91/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0033
# Epoch 92/100
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0033
# Epoch 93/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0033
# Epoch 94/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0032
# Epoch 95/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0032
# Epoch 96/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0031
# Epoch 97/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0031
# Epoch 98/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0031
# Epoch 99/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0031
# Epoch 100/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0031
# 1/1 [==============================] - 0s 234ms/step - loss: 0.2054
# 테스트 데이터 손실: 0.2054
# 1/1 [==============================] - 0s 189ms/step
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45796 (\N{HANGUL SYLLABLE DA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48320 (\N{HANGUL SYLLABLE BYEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47049 (\N{HANGUL SYLLABLE RYANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54872 (\N{HANGUL SYLLABLE HWAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50984 (\N{HANGUL SYLLABLE YUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50696 (\N{HANGUL SYLLABLE YE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52769 (\N{HANGUL SYLLABLE CEUG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44208 (\N{HANGUL SYLLABLE GYEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44284 (\N{HANGUL SYLLABLE GWA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49892 (\N{HANGUL SYLLABLE SIL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 4-2. 모델 학습

# %% [markdown]
# #### 4-2-1. RNN 모델

# %%
# import numpy as np
# import matplotlib.pyplot as plt
# from keras.models import Sequential
# from keras.layers import SimpleRNN, Dense

# # 임의의 예제 데이터 생성
# X = np.random.rand(100, 1, 10)
# Y = np.random.rand(100, 10)

# # RNN 모델 구성
# model = Sequential()
# model.add(SimpleRNN(32, input_shape=(1, 10)))
# model.add(Dense(10, activation='softmax'))

# # 모델 학습 설정
# model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# # 모델 학습
# history = model.fit(X, Y, epochs=10)

# # 성능 확인을 위한 시각화
# plt.figure(figsize=(12, 4))

# plt.subplot(1, 2, 1)
# plt.plot(history.history['loss'], 'b-', label='loss')
# plt.xlabel('Epoch')
# plt.legend()

# plt.subplot(1, 2, 2)
# plt.plot(history.history['accuracy'], 'g-', label='accuracy')
# plt.xlabel('Epoch')
# plt.legend()

# plt.show()
# Out:
# Epoch 1/10
# 4/4 [==============================] - 2s 12ms/step - loss: 11.9941 - accuracy: 0.1200
# Epoch 2/10
# 4/4 [==============================] - 0s 7ms/step - loss: 12.0061 - accuracy: 0.1200
# Epoch 3/10
# 4/4 [==============================] - 0s 5ms/step - loss: 12.0231 - accuracy: 0.1200
# Epoch 4/10
# 4/4 [==============================] - 0s 6ms/step - loss: 12.0413 - accuracy: 0.1200
# Epoch 5/10
# 4/4 [==============================] - 0s 6ms/step - loss: 12.0615 - accuracy: 0.1100
# Epoch 6/10
# 4/4 [==============================] - 0s 7ms/step - loss: 12.0832 - accuracy: 0.1100
# Epoch 7/10
# 4/4 [==============================] - 0s 6ms/step - loss: 12.1080 - accuracy: 0.1100
# Epoch 8/10
# 4/4 [==============================] - 0s 8ms/step - loss: 12.1340 - accuracy: 0.1100
# Epoch 9/10
# 4/4 [==============================] - 0s 8ms/step - loss: 12.1600 - accuracy: 0.1200
# Epoch 10/10
# 4/4 [==============================] - 0s 5ms/step - loss: 12.1826 - accuracy: 0.1200

# %% [markdown]
# ### 4-3. 모델 검증

# %% [markdown]
# ## 5. 계산 모델 구축

# %% [markdown]
# ### 5.1 알고리즘 구현

# %% [markdown]
# ### 5-2. 결과 및 검증

# %% [markdown]
# ## 6. 결과 분석

# %% [markdown]
# ### 6-1. 결과 해석 및 시각화
